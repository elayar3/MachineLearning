# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from pandas.core.common import random_state

# %%
df = pd.read_csv('/content/drive/MyDrive/AIML/MLCass/week1/Assignment/MultipleLinearRegresion/minihomeprices.csv')
df.head()
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000

# %%
df.isna().sum()
# Out:
# area        0
# bedrooms    1
# age         0
# price       0
# dtype: int64

# %%
df['bedrooms']= df['bedrooms'].fillna(df['bedrooms'].mean())
df.isna().sum()
# Out:
# area        0
# bedrooms    0
# age         0
# price       0
# dtype: int64

# %%
plt.figure(figsize=(10,7))
plt.title('Bedroom vs Price')
sns.histplot(df['bedrooms'])
plt.xlabel('Bedroom')
plt.ylabel('Price')
plt.show()

# %%
mlr=LinearRegression()

# %%
X=df.iloc[:, :3]
y=df.iloc[:, -1]
print(X)
print(y)
# Out:
#    area  bedrooms  age
# 0  2600       3.0   20
# 1  3000       4.0   15
# 2  3200       4.2   18
# 3  3600       3.0   30
# 4  4000       5.0    8
# 5  4100       6.0    8
# 0    550000
# 1    565000
# 2    610000
# 3    595000
# 4    760000
# 5    810000
# Name: price, dtype: int64

# %%
mlr.fit(X,y)
# Out:
# LinearRegression()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
mlr.predict(X_train)
# Out:
# array([601483.40843428, 597592.55691169, 517680.56257679, 762639.45982935])

# %%
mlr.predict(X_test)
# Out:
# array([793062.69844975, 617541.31379815])

# %%
mlr.coef_
# Out:
# array([  116.66950551, 18756.28806982, -3675.75111708])

# %%
mlr.intercept_
# Out:
# np.float64(231586.00639409182)
